# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import os

# %%
mainpath = "../../datasets"
filename = "titanic/titanic3.csv"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv(fullpath)

# %% [markdown]
# ## Ejemplos de parámetros de la función Read CSV
#
#
#     read.csv(filepath="../../datasets/titanic/titanic3.csv",
#          sep=",", #Separador
#          dtype=None, #{"ingresos":np.float64, "edad":np.int32} #Tipo de dato de las columnas
#          header=0, #Qué fila es la cabecera
#          names= {"ingresos", "edad"}, #Cambio de nombres de las columnas
#          skiprows=12, #Filas a saltar cuando se lee el archivo
#          index_col=0, #Cuál columna será la de etiquetas
#          skip_blank_lines=True, #Se saltean las filas en blanco en vez de poner NaN
#          na_filter=True #Elimina las filas con valores NaN desconocidos
#            )

# %% [markdown]
# ## Carga de datos usando la función OPEN

# %%
data3 = open(mainpath + "/" + 'customer-churn-model/Customer Churn Model.txt', "r")

# %%
cols = data3.readline().strip().split(',')

n_cols = len(cols)

# %%
counter = 0
main_dict = {}

for col in cols:
    main_dict[col] = []

# %%
for line in data3:
    values = line.strip().split(",")
    
    for i in range(len(cols)):
        main_dict[cols[i]].append(values[i])
    
    counter += 1

print("Hola, terminé")
print("El dataset tiene %d filas y %d columnas" % (counter, n_cols))
# Out:
# Hola, terminé
# El dataset tiene 3333 filas y 21 columnas

# %% [markdown]
# ## Lectura y escritura de ficheros

# %%
infile = mainpath + "/" + "customer-churn-model/Customer Churn Model.txt"
outfile = mainpath + "/" + "customer-churn-model/Tab Customer Churn Model.txt"

# %%
with open(infile, "r") as infile1:
    with open(outfile, "w") as outfile1:
        for line in infile1:
            fields = line.strip().split(",")
            outfile1.write("\t".join(fields))
            outfile1.write("\n")

# %%
df4 = pd.read_csv(outfile, sep = "\t")
df4
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
'''
medallasURL = "http://winterolympicsmedals.com/medals.csv" #No existe más la URL
medals_data = pd.read_csv(medallasURL)
'''
# Out:
# '\nmedallasURL = "http://winterolympicsmedals.com/medals.csv" #No existe más la URL\nmedals_data = pd.read_csv(medallasURL)\n'

# %%
'''
import urllib3
http = urllib3.PoolManager()
r = http.request('GET', medallasURL)
r.status
response = r.data
'''

'''
import csv
cr = csv.reader(response)
'''

'''
for row in cr:
    print(row)
'''

# %% [markdown]
# ## Ficheros XLS y XLSX

# %%
filename = "titanic/titanic3.xls"

# %%
titanic2 = pd.read_excel(mainpath + "/" + filename, sheet_name="titanic3")

# %%
titanic2.to_csv(mainpath + "/titanic/titanic_custom.csv")

# %%
titanic2.to_excel(mainpath + "/titanic/titanic_custom2.xls")

# %%
titanic2.to_json(mainpath + "/titanic/titanic_custom2.json")
